# %% [markdown]
# # Exceptions

# %% [markdown]
# ### Constantes matemáticas simples

# %%
circumference = 2 * Math.PI * radius

# %% [markdown]
# ### Valores iniciais ou incrementais num loop

# %%
for ( i = 0; i < max; i += 1)
